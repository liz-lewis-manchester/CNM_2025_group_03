# %% [markdown]
# <a href="https://colab.research.google.com/github/liz-lewis-manchester/CNM_2025_group_03/blob/main/Initialising_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

#Physical Parameters
L=float(input("Enter the value for the domain size for Length (m): ")) #Length of river
T=float(input("Enter the value for the domain size of time (s): ")) #Duration of the simulation

#Initialising variables to 0
Nx=0 #Total number of points
dx=0 #Distance between each points
Nt=0 #Total number of time steps
dt=0 #Duration of each time step

#Allows user to choose between the number of points or step size
print("Case a: You can enter the values for Nx and Nt")
print("Case b: You can enter the values for dx and dt")
Case=input("Enter a for Case a or b for Case b: ")


if Case=="Case a":
    Nx=int(input("Enter the value for Nx: "))
    Nt=int(input("Enter the value for Nt: "))
    dx=L/(Nx)
    d=T/(Nt)
else:
    dx=float(input("Enter dx: "))
    dt=float(input("Enter dt: "))
    Nx=int(round(L/dx))+1
    Nt=int(round(T/dt))+1

#outputs values for parameters
print("Parameters")
print("Length (m): ",L)
print("Time (sec): ",T)
print()
print("Nx: ",Nx)
print("Nt: ",Nt)
print()
print("dx(m) :",dx)
print("dt(sec) :",dt)

#Initialising arrays to 0

#Arrays that hold solutons
Theta_old=np.zeros(Nx-1) #solution vector at old step
Theta_new=np.zeros(Nx-1) #solution vector at new step

#Arrays that build up the linear system of equation
A=np.zeros(Nx-2) #Matrix Coefficient of LHS
B=np.zeros(Nx-2) #Matrix Coefficient of LHS
F=np.zeros(Nx-2) #RHS of the equation
